# %%
import requests

# %%
subscription_key = "50eb599c6934473ab4bb88f245675d89"
assert subscription_key

# %%
search_url = "https://api.cognitive.microsoft.com/bing/v7.0/images/search"
search_term = "Ali Al-Ahmed"

# %%
headers = {"Ocp-Apim-Subscription-Key" : subscription_key}
params  = {"q": search_term, "imageType": "photo"}
response = requests.get(search_url, headers=headers, params=params)
response.raise_for_status()
search_results = response.json()

# %%
thumbnail_urls = [img["thumbnailUrl"] + '&c=7&w=250&h=250' for img in search_results["value"][:40]]

# %%
thumbnail_urls
# Out:
# ['https://tse4.mm.bing.net/th?id=OIP.72fGwDQIFo30nw-KTvWgywHaEK&pid=Api&c=7&w=250&h=250',
#  'https://tse4.mm.bing.net/th?id=OIP.tVh2u3uqOY2fkmdGAuNxawAAAA&pid=Api&c=7&w=250&h=250',
#  'https://tse4.mm.bing.net/th?id=OIP.nmwvU9ZMuC7jigUz1uQNsQHaEK&pid=Api&c=7&w=250&h=250',
#  'https://tse3.mm.bing.net/th?id=OIP.VkcKZwBU2tOhZmDM6DIIpAHaFH&pid=Api&c=7&w=250&h=250',
#  'https://tse4.mm.bing.net/th?id=OIP.jkk6UxKgH0IJ2JMeWwFZpwHaHa&pid=Api&c=7&w=250&h=250',
#  'https://tse1.mm.bing.net/th?id=OIP.Z6gGlAxGkiqcOFyMW2MIOQHaKh&pid=Api&c=7&w=250&h=250',
#  'https://tse2.mm.bing.net/th?id=OIP.wtd_QOZrfRFGGrIxpH-u8gHaEK&pid=Api&c=7&w=250&h=250',
#  'https://tse3.mm.bing.net/th?id=OIP.7UelnizyDL9pi6aOp_o7OAHaE8&pid=Api&c=7&w=250&h=250',
#  'https://tse2.mm.bing.net/th?id=OIP.KnaXKbs7RDUu8Tqm0y9YqgHaEK&pid=Api&c=7&w=250&h=250',
#  'https://tse2.mm.bing.net/th?id=OIP.Rc9R6tTjv6Q_CFpJG31a5AAAAA&pid=Api&c=7&w=250&h=250',
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from PIL import Image
from io import BytesIO

f, axes = plt.subplots(10, 4, figsize=(20,40))
for i in range(10):
    for j in range(4):
        image_data = requests.get(thumbnail_urls[i+4*j])
        image_data.raise_for_status()
        image = Image.open(BytesIO(image_data.content))        
        axes[i][j].imshow(image)
        axes[i][j].axis("off")
